                      0.7018730489073881, 0.7089836975372875, 0.7124523066250433, 0.7129725979882068, 
                      0.7072493929934096, 0.7043010752688172, 0.7169614984391259, 0.7114117238987167, 
                      0.7211238293444329, 0.719389524800555, 0.7134928893513701, 0.7131460284425946, 
                      0.7171349288935137, 0.7221644120707597, 0.7166146375303504, 0.7273673257023934, 
                      0.7190426638917794, 0.7124523066250433, 0.7271938952480056, 0.7238987166146376, 
                      0.7167880679847382, 0.7070759625390218, 0.7278876170655567, 0.723551855705862, 
                      0.7289281997918835, 0.7155740548040236, 0.7225112729795352, 0.723551855705862, 
                      0.7263267429760666, 0.7348248352410683, 0.725979882067291, 0.7282344779743323, 
                      0.7206035379812695, 0.7232049947970863, 0.7273673257023934, 0.7315296566077003, 
                      0.7280610475199445, 0.711064862989941, 0.7337842525147416, 0.723551855705862, 
                      0.7277141866111689, 0.7230315643426986, 0.7351716961498439, 0.7261533125216788, 
                      0.7232049947970863]

reference_char_error = [0.9838042269187987, 0.8809788654060067, 0.5203559510567297, 0.33205784204671857, 
                      0.29054505005561737, 0.2439599555061179, 0.2181979977753059, 0.20262513904338153, 
                      0.18593993325917688, 0.18740823136818688, 0.17259176863181314, 0.1646273637374861, 
                      0.16347052280311458, 0.15830923248053394, 0.14696329254727475, 0.1495884315906563, 
                      0.14197997775305896, 0.1457174638487208, 0.14189098998887653, 0.137174638487208, 
                      0.13490545050055616, 0.13152391546162404, 0.13094549499443828, 0.1332146829810901, 
                      0.13090100111234707, 0.1254282536151279, 0.12525027808676306, 0.12529477196885427, 
                      0.12596218020022246, 0.12596218020022246, 0.12182424916573971, 0.12262513904338153, 
                      0.11942157953281424, 0.12031145717463848, 0.11839822024471636, 0.11661846496106786, 
                      0.12195773081201335, 0.11853170189099, 0.11608453837597331, 0.11719688542825361, 
                      0.12048943270300334, 0.12088987764182425, 0.11599555061179088, 0.11781979977753058, 
                      0.11506117908787541, 0.11546162402669632, 0.11692992213570634, 0.11790878754171301, 
                      0.11612903225806452, 0.11412680756395996, 0.11688542825361513, 0.11101223581757508, 
                      0.11568409343715239, 0.12017797552836484, 0.11350389321468297, 0.11541713014460511, 
                      0.1181757508342603, 0.11875417130144605, 0.11105672969966629, 0.11350389321468297, 
                      0.11234705228031146, 0.11688542825361513, 0.11461624026696329, 0.11154616240266964, 
                      0.11359288097886541, 0.10914349276974417, 0.11283648498331479, 0.11332591768631813, 
                      0.11394883203559511, 0.11492769744160178, 0.11119021134593993, 0.11145717463848721, 
                      0.11265850945494994, 0.11804226918798665, 0.11092324805339265, 0.11648498331479422, 
                      0.1135483870967742, 0.11599555061179088, 0.11154616240266964, 0.11279199110122358, 
                      0.11421579532814238]

# %%
import numpy as np
x = np.linspace(1, len(word_accuracy), num=len(word_accuracy))
y = np.asarray(word_accuracy)
x2 = np.linspace(1, len(reference_accuracy), num=len(reference_accuracy))
y2 = np.asarray(reference_accuracy)

# %%
#plt.plot(x2,y2,label=f"Reference ({np.around(np.max(y2), decimals=2)})")
plt.plot(x,y,label=f"Max accuracy:{np.around(np.max(y), decimals=2)}")
plt.xlabel('epochs')
plt.ylabel('word accuracy')
plt.legend()
#plt.title("Word accuracy comparison", fontsize=12)
#plt.show()
plt.savefig('word_accuracy.png', dpi=200)

# %%
x = np.linspace(1, len(char_error), num=len(char_error))
y = np.asarray(char_error)
x2 = np.linspace(1, len(reference_char_error), num=len(reference_char_error))
y2 = np.asarray(reference_char_error)

# %%
len(char_error)
# Out:
# 70

# %%
#plt.plot(x2,y2,label=f"Reference ({np.around(np.min(y2), decimals=2)})")
plt.plot(x,y,label=f"Min error:{np.around(np.min(y), decimals=2)}")
plt.xlabel('epochs')
plt.ylabel('character error rate')
plt.legend()
#plt.title("Character error rate", fontsize=15, color="green")
#plt.show()
plt.savefig('char_error_rate.png', dpi=200)
